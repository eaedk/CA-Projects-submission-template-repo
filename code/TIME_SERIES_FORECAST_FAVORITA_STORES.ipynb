# %% [markdown]
# # BEIJING

# %% [markdown]
# # **Forecasting Retail Sales using Time Series Models.**

# %% [markdown]
# **DESCRIPTION:**
#
# The objective of this project is to develop a robust time series forecasting model that can accurately predict the unit sales for various items sold in Favorita stores. Favorita is a leading grocery retailer based in Ecuador, and the company's sales data will be used to build the model. The data set contains sales data for thousands of items sold at different stores, making it a challenging and complex problem.
#
# To build an accurate forecasting model, various statistical and machine learning techniques will be used. The data will be preprocessed to ensure that it is clean, consistent, and in the right format for analysis. Exploratory data analysis (EDA) techniques will be employed to gain a deeper understanding of the data and identify any patterns or trends in the sales data.
#
# Time series forecasting models, such as ARIMA, Linear regression and machine learning model-Prophet will be used to predict store sales. These models will be trained using historical sales data, and their accuracy will be evaluated using various performance metrics such as root mean square logarithmic error, root mean squared error (RMSE), and mean square error (MSE).
#
# The results obtained from the forecasting models will be analyzed, and insights gained from the analysis will be used to make informed business decisions. The insights could include identifying which products have high demand at different times of the year, which stores perform better than others, and identifying any trends in sales data that could inform marketing and inventory decisions.
#
# Overall, the project aims to build a reliable time series forecasting model that can help Favorita optimize their sales strategies and improve their bottom line.

# %% [markdown]
# **QUESTIONS ASKED OF THE DATA**
#
# -Is the train dataset complete (has all the required dates)?
#
# -Which dates have the lowest and highest sales for each year?
#
# -Did the earthquake impact sales?
#
# -Are certain groups of stores selling more products? (Cluster, city, state, type)
#
# -Are sales affected by promotions, oil prices and holidays?
#
# -What analysis can we get from the date and its extractable features?
#
# -What is the difference between RMSLE, RMSE, MSE (or why is the MAE greater than all of them?)
#
# Your task is to build a model that more accurately predicts the unit sales for thousands of items.

# %% [markdown]
# **Hypothesis**
#
# The location of Favorita stores has an impact on the sales of specific items, and stores located in certain regions sell more of certain items compared to others. By identifying these regional trends and patterns, Favorita can optimize its store layout, product selection, and marketing strategies to better serve its customers and increase sales.
#
# **Null Hypothesis(H0):**
#
# There is no relationship between the location of Favorita stores and the sales of specific items.
#
# **Alternative Hypothesis(HA):**
#
# The location of Favorita stores has an impact on the sales of specific items.

# %%
# !pip install summarytools
# Out:
# Requirement already satisfied: summarytools in c:\users\donto\anaconda3\lib\site-packages (0.2.3)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\donto\anaconda3\lib\site-packages (from summarytools) (1.4.4)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\donto\anaconda3\lib\site-packages (from summarytools) (1.21.5)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\donto\anaconda3\lib\site-packages (from summarytools) (3.5.2)
# Requirement already satisfied: ipython>=7.20.0 in c:\users\donto\anaconda3\lib\site-packages (from summarytools) (7.31.1)
# Requirement already satisfied: pickleshare in c:\users\donto\anaconda3\lib\site-packages (from ipython>=7.20.0->summarytools) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\donto\anaconda3\lib\site-packages (from ipython>=7.20.0->summarytools) (3.0.20)
# Requirement already satisfied: colorama in c:\users\donto\anaconda3\lib\site-packages (from ipython>=7.20.0->summarytools) (0.4.5)
# Requirement already satisfied: matplotlib-inline in c:\users\donto\anaconda3\lib\site-packages (from ipython>=7.20.0->summarytools) (0.1.6)
# Requirement already satisfied: traitlets>=4.2 in c:\users\donto\anaconda3\lib\site-packages (from ipython>=7.20.0->summarytools) (5.1.1)
# Requirement already satisfied: pygments in c:\users\donto\anaconda3\lib\site-packages (from ipython>=7.20.0->summarytools) (2.11.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\donto\anaconda3\lib\site-packages (from ipython>=7.20.0->summarytools) (0.18.1)
# Requirement already satisfied: backcall in c:\users\donto\anaconda3\lib\site-packages (from ipython>=7.20.0->summarytools) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\donto\anaconda3\lib\site-packages (from ipython>=7.20.0->summarytools) (63.4.1)
# Requirement already satisfied: decorator in c:\users\donto\anaconda3\lib\site-packages (from ipython>=7.20.0->summarytools) (5.1.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\donto\anaconda3\lib\site-packages (from matplotlib>=3.3.0->summarytools) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\donto\anaconda3\lib\site-packages (from matplotlib>=3.3.0->summarytools) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\donto\anaconda3\lib\site-packages (from matplotlib>=3.3.0->summarytools) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\donto\anaconda3\lib\site-packages (from matplotlib>=3.3.0->summarytools) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\donto\anaconda3\lib\site-packages (from matplotlib>=3.3.0->summarytools) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\donto\anaconda3\lib\site-packages (from matplotlib>=3.3.0->summarytools) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\donto\anaconda3\lib\site-packages (from matplotlib>=3.3.0->summarytools) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\donto\anaconda3\lib\site-packages (from pandas>=1.4.0->summarytools) (2022.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\donto\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.20.0->summarytools) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\donto\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.20.0->summarytools) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\donto\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->summarytools) (1.16.0)

# %%
# !pip install prophet
# Out:
# Requirement already satisfied: prophet in c:\users\donto\anaconda3\lib\site-packages (1.1.2)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\donto\anaconda3\lib\site-packages (from prophet) (3.5.2)
# Requirement already satisfied: convertdate>=2.1.2 in c:\users\donto\anaconda3\lib\site-packages (from prophet) (2.4.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\donto\anaconda3\lib\site-packages (from prophet) (2.8.2)
# Requirement already satisfied: tqdm>=4.36.1 in c:\users\donto\anaconda3\lib\site-packages (from prophet) (4.64.1)
# Requirement already satisfied: holidays>=0.14.2 in c:\users\donto\anaconda3\lib\site-packages (from prophet) (0.24)
# Requirement already satisfied: cmdstanpy>=1.0.4 in c:\users\donto\anaconda3\lib\site-packages (from prophet) (1.1.0)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\donto\anaconda3\lib\site-packages (from prophet) (1.21.5)
# Requirement already satisfied: pandas>=1.0.4 in c:\users\donto\anaconda3\lib\site-packages (from prophet) (1.4.4)
# Requirement already satisfied: LunarCalendar>=0.0.9 in c:\users\donto\anaconda3\lib\site-packages (from prophet) (0.0.9)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in c:\users\donto\anaconda3\lib\site-packages (from convertdate>=2.1.2->prophet) (0.5.12)
# Requirement already satisfied: korean-lunar-calendar in c:\users\donto\anaconda3\lib\site-packages (from holidays>=0.14.2->prophet) (0.3.1)
# Requirement already satisfied: hijri-converter in c:\users\donto\anaconda3\lib\site-packages (from holidays>=0.14.2->prophet) (2.3.1)
# Requirement already satisfied: ephem>=3.7.5.3 in c:\users\donto\anaconda3\lib\site-packages (from LunarCalendar>=0.0.9->prophet) (4.1.4)
# Requirement already satisfied: pytz in c:\users\donto\anaconda3\lib\site-packages (from LunarCalendar>=0.0.9->prophet) (2022.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\donto\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\donto\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\donto\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\donto\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\donto\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\donto\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (4.25.0)
# Requirement already satisfied: six>=1.5 in c:\users\donto\anaconda3\lib\site-packages (from python-dateutil>=2.8.0->prophet) (1.16.0)
# Requirement already satisfied: colorama in c:\users\donto\anaconda3\lib\site-packages (from tqdm>=4.36.1->prophet) (0.4.5)

# %%
##from google.colab import drive

# %%
##drive.mount('/content/drive')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from summarytools import dfSummary
import warnings
from scipy.stats import f_oneway
from sklearn.preprocessing import OneHotEncoder
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import statsmodels.api as sm
from prophet import Prophet
from sklearn.preprocessing import StandardScaler
#from sklearn.metrics import mean_squared_error,mean_absolute_error
warnings.filterwarnings('ignore')

# %% [markdown]
# DATA LOADING

# %%
df_holiday_events=pd.read_csv('store-sales-time-series-forecasting/holidays_events.csv')
df_oil=pd.read_csv('store-sales-time-series-forecasting/oil.csv')
df_stores=pd.read_csv('store-sales-time-series-forecasting/stores.csv')
df_transactions=pd.read_csv('store-sales-time-series-forecasting/transactions.csv')
test_set=pd.read_csv('store-sales-time-series-forecasting/test.csv')
train_set=pd.read_csv('store-sales-time-series-forecasting/train.csv')
pd.set_option('display.max_columns', None)

# %% [markdown]
# # **EXPLORATORY DATA ANALYSIS**

# %% [markdown]
# *INSPECT EACH DATASET SET SEPARATELY*

# %% [markdown]
# ***HOLIDAY EVENTS DATASET***

# %%
df_holiday_events.head()
# Out:
#          date     type    locale locale_name                    description  \
# 0  2012-03-02  Holiday     Local       Manta             Fundacion de Manta
# 1  2012-04-01  Holiday  Regional    Cotopaxi  Provincializacion de Cotopaxi
# 2  2012-04-12  Holiday     Local      Cuenca            Fundacion de Cuenca
# 3  2012-04-14  Holiday     Local    Libertad      Cantonizacion de Libertad
# 4  2012-04-21  Holiday     Local    Riobamba      Cantonizacion de Riobamba
#
#    transferred
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False

# %%
df_holiday_events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         350 non-null    object
#  1   type         350 non-null    object
#  2   locale       350 non-null    object
#  3   locale_name  350 non-null    object
#  4   description  350 non-null    object
#  5   transferred  350 non-null    bool
# dtypes: bool(1), object(5)
# memory usage: 14.1+ KB

# %%
#Convert the date datatype from object to date.
df_holiday_events['date']=pd.to_datetime(df_holiday_events.date)

# %%
#Check for duplicate entries.

df_holiday_events.duplicated().value_counts()
# Out:
# False    350
# dtype: int64

# %%
dfSummary(df_holiday_events,is_collapsible=True)
# Out:
# <button type="button" class = "st-collapsible",
#     id = "btn-1614" onclick = "coll_toggle_1614()">Show Summary - df_holiday_events</button>
#     <div class="st-content" id="cont-1614">
#       <style type="text/css">
# #T_6a729 thead>tr>th {
#   text-align: left;
# }
# #T_6a729_row0_col0, #T_6a729_row1_col0, #T_6a729_row2_col0, #T_6a729_row3_col0, #T_6a729_row4_col0, #T_6a729_row5_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_6a729_row0_col1, #T_6a729_row1_col1, #T_6a729_row2_col1, #T_6a729_row3_col1, #T_6a729_row4_col1, #T_6a729_row5_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_6a729_row0_col2, #T_6a729_row1_col2, #T_6a729_row2_col2, #T_6a729_row3_col2, #T_6a729_row4_col2, #T_6a729_row5_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_6a729_row0_col3, #T_6a729_row1_col3, #T_6a729_row2_col3, #T_6a729_row3_col3, #T_6a729_row4_col3, #T_6a729_row5_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_6a729_row0_col4, #T_6a729_row1_col4, #T_6a729_row2_col4, #T_6a729_row3_col4, #T_6a729_row4_col4, #T_6a729_row5_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_6a729_row0_col5, #T_6a729_row1_col5, #T_6a729_row2_col5, #T_6a729_row3_col5, #T_6a729_row4_col5, #T_6a729_row5_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_6a729">
#   <caption><strong>Data Frame Summary</strong><br>df_holiday_events<br>Dimensions: 350 x 6<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_6a729_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_6a729_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_6a729_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_6a729_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_6a729_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_6a729_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6a729_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_6a729_row0_col1" class="data row0 col1" ><strong>date</strong><br>[datetime64[ns]]</td>
#       <td id="T_6a729_row0_col2" class="data row0 col2" >Min: 2012-03-02<br>Max: 2017-12-26<br>Duration: 2,125 days</td>
#       <td id="T_6a729_row0_col3" class="data row0 col3" >312 distinct values</td>
#       <td id="T_6a729_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_6a729_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_6a729_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_6a729_row1_col1" class="data row1 col1" ><strong>type</strong><br>[object]</td>
#       <td id="T_6a729_row1_col2" class="data row1 col2" >1. Holiday<br>2. Event<br>3. Additional<br>4. Transfer<br>5. Bridge<br>6. Work Day</td>
#       <td id="T_6a729_row1_col3" class="data row1 col3" >221 (63.1%)<br>56 (16.0%)<br>51 (14.6%)<br>12 (3.4%)<br>5 (1.4%)<br>5 (1.4%)</td>
#       <td id="T_6a729_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_6a729_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_6a729_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_6a729_row2_col1" class="data row2 col1" ><strong>locale</strong><br>[object]</td>
#       <td id="T_6a729_row2_col2" class="data row2 col2" >1. National<br>2. Local<br>3. Regional</td>
#       <td id="T_6a729_row2_col3" class="data row2 col3" >174 (49.7%)<br>152 (43.4%)<br>24 (6.9%)</td>
#       <td id="T_6a729_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_6a729_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_6a729_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_6a729_row3_col1" class="data row3 col1" ><strong>locale_name</strong><br>[object]</td>
#       <td id="T_6a729_row3_col2" class="data row3 col2" >1. Ecuador<br>2. Quito<br>3. Riobamba<br>4. Guaranda<br>5. Latacunga<br>6. Ambato<br>7. Guayaquil<br>8. Cuenca<br>9. Ibarra<br>10. Salinas<br>11. other</td>
#       <td id="T_6a729_row3_col3" class="data row3 col3" >174 (49.7%)<br>13 (3.7%)<br>12 (3.4%)<br>12 (3.4%)<br>12 (3.4%)<br>12 (3.4%)<br>11 (3.1%)<br>7 (2.0%)<br>7 (2.0%)<br>6 (1.7%)<br>84 (24.0%)</td>
#       <td id="T_6a729_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_6a729_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_6a729_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_6a729_row4_col1" class="data row4 col1" ><strong>description</strong><br>[object]</td>
#       <td id="T_6a729_row4_col2" class="data row4 col2" >1. Carnaval<br>2. Fundacion de Cuenca<br>3. Fundacion de Ibarra<br>4. Fundacion de Quito<br>5. Provincializacion de Santo Dom<br>6. Provincializacion Santa Elena<br>7. Independencia de Guaranda<br>8. Independencia de Latacunga<br>9. Independencia de Ambato<br>10. Fundacion de Quito-1<br>11. other</td>
#       <td id="T_6a729_row4_col3" class="data row4 col3" >10 (2.9%)<br>7 (2.0%)<br>7 (2.0%)<br>6 (1.7%)<br>6 (1.7%)<br>6 (1.7%)<br>6 (1.7%)<br>6 (1.7%)<br>6 (1.7%)<br>6 (1.7%)<br>284 (81.1%)</td>
#       <td id="T_6a729_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_6a729_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_6a729_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_6a729_row5_col1" class="data row5 col1" ><strong>transferred</strong><br>[bool]</td>
#       <td id="T_6a729_row5_col2" class="data row5 col2" >1. False<br>2. True</td>
#       <td id="T_6a729_row5_col3" class="data row5 col3" >338 (96.6%)<br>12 (3.4%)</td>
#       <td id="T_6a729_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_6a729_row5_col5" class="data row5 col5" >0<br>(0.0%)</td>
#     </tr>
#   </tbody>
# </table>
#
#     </div>
#     <style>
#     #btn-1614.st-collapsible {
#       background-color: white;
#       color: #444;
#       cursor: pointer;
#       padding: 1.5rem 2rem;
#       width: 100%;
#       text-align: left;
#       outline: none;
#       font-size: 14px;
#       border-top-left-radius: 0.375rem;
#       border-top-right-radius: 0.375rem;
#       border: 1px solid #dee2e6;
#       border-bottom: none;
#       font-weight: 500;
#     }
#
#     #btn-1614.active {
#       background-color: #e7f1ff;
#       color: #0c63e4;
#     }
#
#     #cont-1614.st-content {
#       padding: 0 10px;
#       background-color: white;
#       max-height: 0;
#       overflow: hidden;
#       transition: max-height 0.2s ease-out;
#       border: 1px solid #dee2e6;
#       border-top: none;
#     }
#
#     #cont-1614.st-content .active {
#       border: 1px solid #dee2e6;
#       border-bottom-left-radius: 0.375rem;
#       border-bottom-right-radius: 0.375rem;
#     }
#
#     #btn-1614.st-collapsible:after {
#       content: '';
#       background-image: url("data:image/svg+xml,%3csvg xmlns='http://www.w3.org/2000/svg' viewBox='0 0 16 16' fill='%23212529'%3e%3cpath fill-rule='evenodd' d='M1.646 4.646a.5.5 0 0 1 .708 0L8 10.293l5.646-5.647a.5.5 0 0 1 .708.708l-6 6a.5.5 0 0 1-.708 0l-6-6a.5.5 0 0 1 0-.708z'/%3e%3c/svg%3e");
#       color: #444;
#       font-weight: bold;
#       float: right;
#       margin-left: 5px;
#       height: 1.5em;
#       width:  1.5rem;
#       background-repeat: no-repeat;
#       transition: transform 0.2s ease-in-out;
#     }
#
#     #btn-1614.active:after {
#       content: '';
#       background-image: url("data:image/svg+xml,%3csvg xmlns='http://www.w3.org/2000/svg' viewBox='0 0 16 16' fill='%230c63e4'%3e%3cpath fill-rule='evenodd' d='M1.646 4.646a.5.5 0 0 1 .708 0L8 10.293l5.646-5.647a.5.5

# %% [markdown]
# **Observations about df_holiday_events DataFrame.**
#
# -There are no missing values in each of the columns.
#
# -The date column had an object data type.
#
# -There are total of 12 transferred holidays in the transferred column.
#
# -There are no duplicate entries in the dataset.

# %% [markdown]
# **Feature creation**
#
# For ease of analysis further down the line, I decided to create stand-alone columns for day,month and year using the date column.

# %%
date = pd.to_datetime(df_holiday_events['date'][0])

# %%
#CREATE INDIVIDUAL YEAR/MONTH/DAY COLUMNS
df_holiday_events['year'] = df_holiday_events['date'].dt.year
df_holiday_events['month'] = df_holiday_events['date'].dt.month
df_holiday_events['day'] = df_holiday_events['date'].dt.day

# %%
df_holiday_events.head()
# Out:
#         date     type    locale locale_name                    description  \
# 0 2012-03-02  Holiday     Local       Manta             Fundacion de Manta
# 1 2012-04-01  Holiday  Regional    Cotopaxi  Provincializacion de Cotopaxi
# 2 2012-04-12  Holiday     Local      Cuenca            Fundacion de Cuenca
# 3 2012-04-14  Holiday     Local    Libertad      Cantonizacion de Libertad
# 4 2012-04-21  Holiday     Local    Riobamba      Cantonizacion de Riobamba
#
#    transferred  year  month  day
# 0        False  2012      3    2
# 1        False  2012      4    1
# 2        False  2012      4   12
# 3        False  2012      4   14
# 4        False  2012      4   21

# %%
#We now set the date as the index for the DataFrame

df_holiday_events = df_holiday_events.set_index('date')

# %%
df_holiday_events.head()
# Out:
#                type    locale locale_name                    description  \
# date
# 2012-03-02  Holiday     Local       Manta             Fundacion de Manta
# 2012-04-01  Holiday  Regional    Cotopaxi  Provincializacion de Cotopaxi
# 2012-04-12  Holiday     Local      Cuenca            Fundacion de Cuenca
# 2012-04-14  Holiday     Local    Libertad      Cantonizacion de Libertad
# 2012-04-21  Holiday     Local    Riobamba      Cantonizacion de Riobamba
#
#             transferred  year  month  day
# date
# 2012-03-02        False  2012      3    2
# 2012-04-01        False  2012      4    1
# 2012-04-12        False  2012      4   12
# 2012-04-14        False  2012      4   14
# 2012-04-21        False  2012      4   21

# %%
#Inspecting the types of the holidays column

holiday_plot = sns.catplot(data=df_holiday_events, x="type",kind="count")
holiday_plot.ax.set_xticklabels(holiday_plot.ax.get_xticklabels(), rotation=45);

# %%
##Visualizing the new data set

holiday_plot = sns.catplot(data=df_holiday_events, x="locale",kind="count")
holiday_plot.ax.set_xticklabels(holiday_plot.ax.get_xticklabels(), rotation=45);

# %%
holiday_plot = sns.catplot(data=df_holiday_events, x="transferred",kind="count")
holiday_plot.ax.set_xticklabels(holiday_plot.ax.get_xticklabels(), rotation=45);

# %% [markdown]
# **OIL DATASET**

# %%
df_oil.head()
# Out:
#          date  dcoilwtico
# 0  2013-01-01         NaN
# 1  2013-01-02       93.14
# 2  2013-01-03       92.97
# 3  2013-01-04       93.12
# 4  2013-01-07       93.20

# %%
df_oil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1218 entries, 0 to 1217
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1218 non-null   object
#  1   dcoilwtico  1175 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 19.2+ KB

# %%
dfSummary(df_oil, is_collapsible=True)
# Out:
# <button type="button" class = "st-collapsible",
#     id = "btn-1869" onclick = "coll_toggle_1869()">Show Summary - df_oil</button>
#     <div class="st-content" id="cont-1869">
#       <style type="text/css">
# #T_d5cde thead>tr>th {
#   text-align: left;
# }
# #T_d5cde_row0_col0, #T_d5cde_row1_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_d5cde_row0_col1, #T_d5cde_row1_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_d5cde_row0_col2, #T_d5cde_row1_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_d5cde_row0_col3, #T_d5cde_row1_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_d5cde_row0_col4, #T_d5cde_row1_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_d5cde_row0_col5, #T_d5cde_row1_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_d5cde">
#   <caption><strong>Data Frame Summary</strong><br>df_oil<br>Dimensions: 1,218 x 2<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_d5cde_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_d5cde_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_d5cde_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_d5cde_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_d5cde_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_d5cde_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d5cde_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_d5cde_row0_col1" class="data row0 col1" ><strong>date</strong><br>[object]</td>
#       <td id="T_d5cde_row0_col2" class="data row0 col2" >1. 2013-01-01<br>2. 2016-02-08<br>3. 2016-02-17<br>4. 2016-02-16<br>5. 2016-02-15<br>6. 2016-02-12<br>7. 2016-02-11<br>8. 2016-02-10<br>9. 2016-02-09<br>10. 2016-02-05<br>11. other</td>
#       <td id="T_d5cde_row0_col3" class="data row0 col3" >1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>1,208 (99.2%)</td>
#       <td id="T_d5cde_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_d5cde_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_d5cde_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_d5cde_row1_col1" class="data row1 col1" ><strong>dcoilwtico</strong><br>[float64]</td>
#       <td id="T_d5cde_row1_col2" class="data row1 col2" >Mean (sd) : 67.7 (25.6)<br>min < med < max:<br>26.2 < 53.2 < 110.6<br>IQR (CV) : 49.3 (2.6)</td>
#       <td id="T_d5cde_row1_col3" class="data row1 col3" >998 distinct values</td>
#       <td id="T_d5cde_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_d5cde_row1_col5" class="data row1 col5" >43<br>(3.5%)</td>
#     </tr>
#   </tbody>
# </table>
#
#     </div>
#     <style>
#     #btn-1869.st-collapsible {
#       background-color: white;
#       color: #444;
#       cursor: pointer;
#       padding: 1.5rem 2rem;
#       width: 100%;
#       text-align: left;
#       outline: none;
#       font-size: 14px;
#       border-top-left-radius: 0.375rem;
#       border-top-right-radius: 0.375rem;
#       border: 1px solid #dee2e6;
#       border-bottom: none;
#       font-weight: 500;
#     }
#
#     #btn-1869.active {
#       background-color: #e7f1ff;
#       color: #0c63e4;
#     }
#
#     #cont-1869.st-content {
#       padding: 0 10px;
#       background-color: white;
#       max-height: 0;
#       overflow: hidden;
#       transition: max-height 0.2s ease-out;
#       border: 1px solid #dee2e6;
#       border-top: none;
#     }
#
#     #cont-1869.st-content .active {
#       border: 1px solid #dee2e6;
#       border-bottom-left-radius: 0.375rem;
#       border-bottom-right-radius: 0.375rem;
#     }
#
#     #btn-1869.st-collapsible:after {
#       content: '';
#       background-image: url("data:image/svg+xml,%3csvg xmlns='http://www.w3.org/2000/svg' viewBox='0 0 16 16' fill='%23212529'%3e%3cpath fill-rule='evenodd' d='M1.646 4.646a.5.5 0 0 1 .708 0L8 10.293l5.646-5.647a.5.5 0 0 1 .708.708l-6 6a.5.5 0 0 1-.708 0l-6-6a.5.5 0 0 1 0-.708z'/%3e%3c/svg%3e");
#       color: #444;
#       font-weight: bold;
#       float: right;
#       margin-left: 5px;
#       height: 1.5em;
#       width:  1.5rem;
#       background-repeat: no-repeat;
#       transition: transform 0.2s ease-in-out;
#     }
#
#     #btn-1869.active:after {
#       content: '';
#       background-image: url("data:image/svg+xml,%3csvg xmlns='http://www.w3.org/2000/svg' viewBox='0 0 16 16' fill='%230c63e4'%3e%3cpath fill-rule='evenodd' d='M1.646 4.646a.5.5 0 0 1 .708 0L8 10.293l5.646-5.647a.5.5 0 0 1 .708.708l-6 6a.5.5 0 0 1-.708 0l-6-6a.5.5 0 0 1 0-.708z'/%3e%3c/svg%3e");
#       transform: rotate(180deg);
#     }
#     </style><script>
#     function coll_toggle_1869(){
#         var coll = document.getElementById("btn-1869");
#         var content = document.getElementById("cont-1869");
#         coll.classList.toggle("active");
#         if (content.style.maxHeight){
#           content.style.maxHeight = null;
#           coll.innerHTML = "Show Summary - df_oil";
#         } else {
#           content.style.maxHeight = content.scrollHeight + "px";
#           coll.innerHTML = "Hide Summary - df_oil";
#         }
#     }
#
#     </script>

# %%
df_oil.duplicated().value_counts()
# Out:
# False    1218
# dtype: int64

# %% [markdown]
# **Observations about df_oil DataFrame**
#
# -There are 43 missing values in the dcoilwtico column.
#
# -There are no duplcate entries in the DataFrame.
#
# -The date column is an object data type.

# %%
#Change the date data type from object to date time

df_oil['date']=pd.to_datetime(df_oil.date)

# %% [markdown]
# **Feature creation**
#
# For ease of analysis further down the line, I decided to create stand-alone columns for day,month and year using the date column.

# %%
date = pd.to_datetime(df_oil['date'][0])

# %%
df_oil['Year']=date.year
df_oil['Month']=date.month
df_oil['Day Name']=date.day_name()

# %%
#We now set the date as the index for the DataFrame

df_oil = df_oil.set_index('date')

# %%
df_oil.head()
# Out:
#             dcoilwtico  Year  Month Day Name
# date
# 2013-01-01         NaN  2013      1  Tuesday
# 2013-01-02       93.14  2013      1  Tuesday
# 2013-01-03       92.97  2013      1  Tuesday
# 2013-01-04       93.12  2013      1  Tuesday
# 2013-01-07       93.20  2013      1  Tuesday

# %%
plt.figure(figsize=(14,3))
df_oil['dcoilwtico'].plot(linewidth=0.5)
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# -There are gaps in the plot that indicates missing oil price values for those points in time. The solution is to extrapolate the price for oil for the relevant dates.
#
# -There is clearly a downward trend in oil prices when viewd across the five (5) yeas under inspection.
#
# -Oil prices in 2013 to mid year 2014 stayed above $80 per barrel.
#
# -The prices started trending downwards from mid 2014 and hit its lowest price at ending of February 2016.
#
# -Price then rose to $50 a barrel in the second quarter of 2016.It has held steady since then.

# %% [markdown]
# <b>MISSING VALUES IN OIL DATASET<b>

# %%
df_oil["dcoilwtico"]=df_oil['dcoilwtico'].interpolate(method='linear')

# %%
plt.figure(figsize=(14,3))
df_oil['dcoilwtico'].plot(linewidth=0.5);

# %% [markdown]
# <b>Stores Dataset<b>

# %%
df_stores.head()
# Out:
#    store_nbr           city                           state type  cluster
# 0          1          Quito                       Pichincha    D       13
# 1          2          Quito                       Pichincha    D       13
# 2          3          Quito                       Pichincha    D        8
# 3          4          Quito                       Pichincha    D        9
# 4          5  Santo Domingo  Santo Domingo de los Tsachilas    D        4

# %%
df_stores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   store_nbr  54 non-null     int64
#  1   city       54 non-null     object
#  2   state      54 non-null     object
#  3   type       54 non-null     object
#  4   cluster    54 non-null     int64
# dtypes: int64(2), object(3)
# memory usage: 2.2+ KB

# %%
dfSummary(df_stores, is_collapsible=True)
# Out:
# <button type="button" class = "st-collapsible",
#     id = "btn-6075" onclick = "coll_toggle_6075()">Show Summary - df_stores</button>
#     <div class="st-content" id="cont-6075">
#       <style type="text/css">
# #T_a7352 thead>tr>th {
#   text-align: left;
# }
# #T_a7352_row0_col0, #T_a7352_row1_col0, #T_a7352_row2_col0, #T_a7352_row3_col0, #T_a7352_row4_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_a7352_row0_col1, #T_a7352_row1_col1, #T_a7352_row2_col1, #T_a7352_row3_col1, #T_a7352_row4_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_a7352_row0_col2, #T_a7352_row1_col2, #T_a7352_row2_col2, #T_a7352_row3_col2, #T_a7352_row4_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_a7352_row0_col3, #T_a7352_row1_col3, #T_a7352_row2_col3, #T_a7352_row3_col3, #T_a7352_row4_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_a7352_row0_col4, #T_a7352_row1_col4, #T_a7352_row2_col4, #T_a7352_row3_col4, #T_a7352_row4_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_a7352_row0_col5, #T_a7352_row1_col5, #T_a7352_row2_col5, #T_a7352_row3_col5, #T_a7352_row4_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_a7352">
#   <caption><strong>Data Frame Summary</strong><br>df_stores<br>Dimensions: 54 x 5<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_a7352_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_a7352_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_a7352_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_a7352_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_a7352_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_a7352_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a7352_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_a7352_row0_col1" class="data row0 col1" ><strong>store_nbr</strong><br>[int64]</td>
#       <td id="T_a7352_row0_col2" class="data row0 col2" >Mean (sd) : 27.5 (15.7)<br>min < med < max:<br>1.0 < 27.5 < 54.0<br>IQR (CV) : 26.5 (1.7)</td>
#       <td id="T_a7352_row0_col3" class="data row0 col3" >54 distinct values</td>
#       <td id="T_a7352_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_a7352_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_a7352_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_a7352_row1_col1" class="data row1 col1" ><strong>city</strong><br>[object]</td>
#       <td id="T_a7352_row1_col2" class="data row1 col2" >1. Quito<br>2. Guayaquil<br>3. Cuenca<br>4. Santo Domingo<br>5. Manta<br>6. Latacunga<br>7. Machala<br>8. Ambato<br>9. Quevedo<br>10. Esmeraldas<br>11. other</td>
#       <td id="T_a7352_row1_col3" class="data row1 col3" >18 (33.3%)<br>8 (14.8%)<br>3 (5.6%)<br>3 (5.6%)<br>2 (3.7%)<br>2 (3.7%)<br>2 (3.7%)<br>2 (3.7%)<br>1 (1.9%)<br>1 (1.9%)<br>12 (22.2%)</td>
#       <td id="T_a7352_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_a7352_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_a7352_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_a7352_row2_col1" class="data row2 col1" ><strong>state</strong><br>[object]</td>
#       <td id="T_a7352_row2_col2" class="data row2 col2" >1. Pichincha<br>2. Guayas<br>3. Santo Domingo de los Tsachilas<br>4. Azuay<br>5. Manabi<br>6. Cotopaxi<br>7. Tungurahua<br>8. Los Rios<br>9. El Oro<br>10. Chimborazo<br>11. other</td>
#       <td id="T_a7352_row2_col3" class="data row2 col3" >19 (35.2%)<br>11 (20.4%)<br>3 (5.6%)<br>3 (5.6%)<br>3 (5.6%)<br>2 (3.7%)<br>2 (3.7%)<br>2 (3.7%)<br>2 (3.7%)<br>1 (1.9%)<br>6 (11.1%)</td>
#       <td id="T_a7352_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_a7352_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_a7352_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_a7352_row3_col1" class="data row3 col1" ><strong>type</strong><br>[object]</td>
#       <td id="T_a7352_row3_col2" class="data row3 col2" >1. D<br>2. C<br>3. A<br>4. B<br>5. E</td>
#       <td id="T_a7352_row3_col3" class="data row3 col3" >18 (33.3%)<br>15 (27.8%)<br>9 (16.7%)<br>8 (14.8%)<br>4 (7.4%)</td>
#       <td id="T_a7352_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_a7352_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_a7352_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_a7352_row4_col1" class="data row4 col1" ><strong>cluster</strong><br>[int64]</td>
#       <td id="T_a7352_row4_col2" class="data row4 col2" >Mean (sd) : 8.5 (4.7)<br>min < med < max:<br>1.0 < 8.5 < 17.0<br>IQR (CV) : 9.0 (1.8)</td>
#       <td id="T_a7352_row4_col3" class="data row4 col3" >17 distinct values</td>
#       <td id="T_a7352_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_a7352_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#   </tbody>
# </table>
#
#     </div>
#     <style>
#     #btn-6075.st-collapsible {
#       background-color: white;
#       color: #444;
#       cursor: pointer;
#       padding: 1.5rem 2rem;
#       width: 100%;
#       text-align: left;
#       outline: none;
#       font-size: 14px;
#       border-top-left-radius: 0.375rem;
#       border-top-right-radius: 0.375rem;
#       border: 1px solid #dee2e6;
#       border-bottom: none;
#       font-weight: 500;
#     }
#
#     #btn-6075.active {
#       background-color: #e7f1ff;
#       color: #0c63e4;
#     }
#
#     #cont-6075.st-content {
#       padding: 0 10px;
#       background-color: white;
#       max-height: 0;
#       overflow: hidden;
#       transition: max-height 0.2s ease-out;
#       border: 1px solid #dee2e6;
#       border-top: none;
#     }
#
#     #cont-6075.st-content .active {
#       border: 1px solid #dee2e6;
#       border-bottom-left-radius: 0.375rem;
#       border-bottom-right-radius: 0.375rem;
#     }
#
#     #btn-6075.st-collapsible:after {
#       content: '';
#       background-image: url("data:image/svg+xml,%3csvg xmlns='http://www.w3.org/2000/svg' viewBox='0 0 16 16' fill='%23212529'%3e%3cpath fill-rule='evenodd' d='M1.646 4.646a.5.5 0 0 1 .708 0L8 10.293l5.646-5.647a.5.5 0 0 1 .708.708l-6 6a.5.5 0 0 1-.708 0l-6-6a.5.5 0 0 1 0-.708z'/%3e%3c/svg%3e");
#       color: #444;
#       font-weight: bold;
#       float: right;
#       margin-left: 5px;
#       height: 1.5em;
#       width:  1.5rem;
#       background-repeat: no-repeat;
#       transition: transform 0.2s ease-in-out;
#     }
#
#     #btn-6075.active:after {
#       content: '';
#       background-image: url("data:image/svg+xml,%3csvg xmlns='http://www.w3.org/2000/svg' viewBox='0 0 16 16' fill='%230c63e4'%3e%3cpath fill-rule='evenodd' d='M1.646 4.646a.5.5 0 0 1 .708 0L8 10.293l5.646-5.647a.5.5 0 0 1 .708.708l-6 6a.5.5 0 0 1-.708 0l-6-6a.5.5 0 0 1 0-.708z'/%3e%3c/svg%3e");
#       transform: rotate(180deg);
#     }
#     </style><script>
#     function coll_toggle_6075(){
#         var coll = document.getElementById("btn-6075");
#         var content = document.getElementById("cont-6075");
#         coll.classList.toggle("active");
#         if (content.style.maxHeight){
#           content.style.maxHeight = null;
#           coll.innerHTML = "Show Summary - df_stores";
#         } else {
#           content.style.maxHeight = content.scrollHeight + "px";
#           coll.innerHTML = "Hide Summary - df_stores";
#         }
#     }
#
#     </script>

# %% [markdown]
# **Observations about the stores dataset.**
#
# -There are no duplicate entries.
#
# -There are no missing values.
#
# -All columns are in their expected data types.

# %%
df_stores.duplicated().value_counts()
# Out:
# False    54
# dtype: int64

# %%
#Visualising the stores data set


# get the count of each state
state_counts = df_stores['state'].value_counts()

# plot the state counts
fig, ax = plt.subplots(figsize=(8, 8))
ax.bar(state_counts.index, state_counts.values)
ax.set_xlabel('State')
ax.set_ylabel('Count')
ax.set_title('State Counts')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observations of the state column.**
#
# -Pichincha has the highest number of favorita stores.
#
# -Guayas has the second highest number of stores.

# %%
store_plot=sns.catplot(data=df_stores,x='city',kind='count',orient='h')
store_plot.ax.set_xticklabels(store_plot.ax.get_xticklabels(), rotation=85);

# %% [markdown]
# **Observations of the city column.**
#
# -The city of Quito which is the capital of Ecuador has the highest number of favorita stores.
#
# -Quito is located in the province of Pichincha this is consistent with the state visualization above.
#
# -This is followed by Guayaquil located in the province of Guayas,this is also consistent with the observations from the state visualization.

# %%
store_plot=sns.catplot(data=df_stores,x='type',kind='count',orient='h')
store_plot.ax.set_xticklabels(store_plot.ax.get_xticklabels());

# %% [markdown]
# **Observations of the store type column.**
#
# -The dominant store type is the D followed by C and A type.

# %%
store_plot=sns.catplot(data=df_stores,x='cluster',kind='count',orient='h')
store_plot.ax.set_xticklabels(store_plot.ax.get_xticklabels(), rotation=45);

# %% [markdown]
# **Observations of the cluster column.**
#
# -Cluster 3,6,10 and 15 are the dominant clusters respectively.

# %% [markdown]
# <b>TRANSACTIONS DATASET<b>

# %%
df_transactions.head()
# Out:
#          date  store_nbr  transactions
# 0  2013-01-01         25           770
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922

# %%
df_transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83488 entries, 0 to 83487
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          83488 non-null  object
#  1   store_nbr     83488 non-null  int64
#  2   transactions  83488 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 1.9+ MB

# %%
dfSummary(df_transactions,is_collapsible=True)
# Out:
# <button type="button" class = "st-collapsible",
#     id = "btn-6551" onclick = "coll_toggle_6551()">Show Summary - df_transactions</button>
#     <div class="st-content" id="cont-6551">
#       <style type="text/css">
# #T_046e8 thead>tr>th {
#   text-align: left;
# }
# #T_046e8_row0_col0, #T_046e8_row1_col0, #T_046e8_row2_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_046e8_row0_col1, #T_046e8_row1_col1, #T_046e8_row2_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_046e8_row0_col2, #T_046e8_row1_col2, #T_046e8_row2_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_046e8_row0_col3, #T_046e8_row1_col3, #T_046e8_row2_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_046e8_row0_col4, #T_046e8_row1_col4, #T_046e8_row2_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_046e8_row0_col5, #T_046e8_row1_col5, #T_046e8_row2_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_046e8">
#   <caption><strong>Data Frame Summary</strong><br>df_transactions<br>Dimensions: 83,488 x 3<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_046e8_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_046e8_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_046e8_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_046e8_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_046e8_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_046e8_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_046e8_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_046e8_row0_col1" class="data row0 col1" ><strong>date</strong><br>[object]</td>
#       <td id="T_046e8_row0_col2" class="data row0 col2" >1. 2017-08-15<br>2. 2017-06-02<br>3. 2017-05-21<br>4. 2017-05-22<br>5. 2017-05-23<br>6. 2017-05-24<br>7. 2017-05-25<br>8. 2017-05-26<br>9. 2017-05-27<br>10. 2017-05-28<br>11. other</td>
#       <td id="T_046e8_row0_col3" class="data row0 col3" >54 (0.1%)<br>54 (0.1%)<br>54 (0.1%)<br>54 (0.1%)<br>54 (0.1%)<br>54 (0.1%)<br>54 (0.1%)<br>54 (0.1%)<br>54 (0.1%)<br>54 (0.1%)<br>82,948 (99.4%)</td>
#       <td id="T_046e8_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_046e8_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_046e8_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_046e8_row1_col1" class="data row1 col1" ><strong>store_nbr</strong><br>[int64]</td>
#       <td id="T_046e8_row1_col2" class="data row1 col2" >Mean (sd) : 26.9 (15.6)<br>min < med < max:<br>1.0 < 27.0 < 54.0<br>IQR (CV) : 27.0 (1.7)</td>
#       <td id="T_046e8_row1_col3" class="data row1 col3" >54 distinct values</td>
#       <td id="T_046e8_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_046e8_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_046e8_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_046e8_row2_col1" class="data row2 col1" ><strong>transactions</strong><br>[int64]</td>
#       <td id="T_046e8_row2_col2" class="data row2 col2" >Mean (sd) : 1694.6 (963.3)<br>min < med < max:<br>5.0 < 1393.0 < 8359.0<br>IQR (CV) : 1033.0 (1.8)</td>
#       <td id="T_046e8_row2_col3" class="data row2 col3" >4,993 distinct values</td>
#       <td id="T_046e8_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_046e8_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#   </tbody>
# </table>
#
#     </div>
#     <style>
#     #btn-6551.st-collapsible {
#       background-color: white;
#       color: #444;
#       cursor: pointer;
#       padding: 1.5rem 2rem;
#       width: 100%;
#       text-align: left;
#       outline: none;
#       font-size: 14px;
#       border-top-left-radius: 0.375rem;
#       border-top-right-radius: 0.375rem;
#       border: 1px solid #dee2e6;
#       border-bottom: none;
#       font-weight: 500;
#     }
#
#     #btn-6551.active {
#       background-color: #e7f1ff;
#       color: #0c63e4;
#     }
#
#     #cont-6551.st-content {
#       padding: 0 10px;
#       background-color: white;
#       max-height: 0;
#       overflow: hidden;
#       transition: max-height 0.2s ease-out;
#       border: 1px solid #dee2e6;
#       border-top: none;
#     }
#
#     #cont-6551.st-content .active {
#       border: 1px solid #dee2e6;
#       border-bottom-left-radius: 0.375rem;
#       border-bottom-right-radius: 0.375rem;
#     }
#
#     #btn-6551.st-collapsible:after {
#       content: '';
#       background-image: url("data:image/svg+xml,%3csvg xmlns='http://www.w3.org/2000/svg' viewBox='0 0 16 16' fill='%23212529'%3e%3cpath fill-rule='evenodd' d='M1.646 4.646a.5.5 0 0 1 .708 0L8 10.293l5.646-5.647a.5.5 0 0 1 .708.708l-6 6a.5.5 0 0 1-.708 0l-6-6a.5.5 0 0 1 0-.708z'/%3e%3c/svg%3e");
#       color: #444;
#       font-weight: bold;
#       float: right;
#       margin-left: 5px;
#       height: 1.5em;
#       width:  1.5rem;
#       background-repeat: no-repeat;
#       transition: transform 0.2s ease-in-out;
#     }
#
#     #btn-6551.active:after {
#       content: '';
#       background-image: url("data:image/svg+xml,%3csvg xmlns='http://www.w3.org/2000/svg' viewBox='0 0 16 16' fill='%230c63e4'%3e%3cpath fill-rule='evenodd' d='M1.646 4.646a.5.5 0 0 1 .708 0L8 10.293l5.646-5.647a.5.5 0 0 1 .708.708l-6 6a.5.5 0 0 1-.708 0l-6-6a.5.5 0 0 1 0-.708z'/%3e%3c/svg%3e");
#       transform: rotate(180deg);
#     }
#     </style><script>
#     function coll_toggle_6551(){
#         var coll = document.getElementById("btn-6551");
#         var content = document.getElementById("cont-6551");
#         coll.classList.toggle("active");
#         if (content.style.maxHeight){
#           content.style.maxHeight = null;
#           coll.innerHTML = "Show Summary - df_transactions";
#         } else {
#           content.style.maxHeight = content.scrollHeight + "px";
#           coll.innerHTML = "Hide Summary - df_transactions";
#         }
#     }
#
#     </script>

# %%
#Check for duplicate entries
df_transactions.duplicated().value_counts()
# Out:
# False    83488
# dtype: int64

# %% [markdown]
# **Observations about Transactions dataset.**
#
# -There are no duplicate entries.
#
# -There are no null values.
#
# -The date column is an object data type.

# %%
#Convert date from Object to Datetime

df_transactions['date']=pd.to_datetime(df_transactions.date)

# %% [markdown]
# **Feature Creation.**
#
# For ease of analysis further down the line, I decided to create stand-alone columns for day,month and year using the date column.

# %%
date = pd.to_datetime(df_transactions['date'][0])

# %%
df_transactions['Year']=date.year
df_transactions['Month']=date.month
df_transactions['Day Name']=date.day_name()

# %%
#We now set the date as the index for the DataFrame

df_transactions = df_transactions.set_index('date')

# %%
df_transactions.head()
# Out:
#             store_nbr  transactions  Year  Month Day Name
# date
# 2013-01-01         25           770  2013      1  Tuesday
# 2013-01-02          1          2111  2013      1  Tuesday
# 2013-01-02          2          2358  2013      1  Tuesday
# 2013-01-02          3          3487  2013      1  Tuesday
# 2013-01-02          4          1922  2013      1  Tuesday

# %%
#Visualizing the transactions dataset
plt.figure(figsize=(12,5))
plt.plot(df_transactions.transactions);

# %% [markdown]
# -There is seasonality in transactions volumes across the years under review.
#
# -The spike in transactions coincides with the shopping frenzy just before the christmas holidays.

# %%
# group the data by store_nbr and count the values, then sort by the count values in descending order
store_counts = df_transactions.groupby('store_nbr')['store_nbr'].count().sort_values(ascending=False)

# create catplot with sorted data and order parameter
transaction_plot = sns.catplot(data=df_transactions, x='store_nbr', kind='count', orient='v', order=store_counts.index)

# adjust figure size
transaction_plot.fig.set_size_inches(12, 5)

# rotate x-axis labels if needed
transaction_plot.set_xticklabels(rotation=45)

# show plot
plt.show()

# %% [markdown]
# <b>TRAIN DATASET<b>

# %%
train_set.head()
# Out:
#    id        date  store_nbr      family  sales  onpromotion
# 0   0  2013-01-01          1  AUTOMOTIVE    0.0            0
# 1   1  2013-01-01          1   BABY CARE    0.0            0
# 2   2  2013-01-01          1      BEAUTY    0.0            0
# 3   3  2013-01-01          1   BEVERAGES    0.0            0
# 4   4  2013-01-01          1       BOOKS    0.0            0

# %%
train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000888 entries, 0 to 3000887
# Data columns (total 6 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   id           int64
#  1   date         object
#  2   store_nbr    int64
#  3   family       object
#  4   sales        float64
#  5   onpromotion  int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 137.4+ MB

# %%
dfSummary(train_set,is_collapsible=True)
# Out:
# <button type="button" class = "st-collapsible",
#     id = "btn-7999" onclick = "coll_toggle_7999()">Show Summary - train_set</button>
#     <div class="st-content" id="cont-7999">
#       <style type="text/css">
# #T_7107a thead>tr>th {
#   text-align: left;
# }
# #T_7107a_row0_col0, #T_7107a_row1_col0, #T_7107a_row2_col0, #T_7107a_row3_col0, #T_7107a_row4_col0, #T_7107a_row5_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_7107a_row0_col1, #T_7107a_row1_col1, #T_7107a_row2_col1, #T_7107a_row3_col1, #T_7107a_row4_col1, #T_7107a_row5_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_7107a_row0_col2, #T_7107a_row1_col2, #T_7107a_row2_col2, #T_7107a_row3_col2, #T_7107a_row4_col2, #T_7107a_row5_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_7107a_row0_col3, #T_7107a_row1_col3, #T_7107a_row2_col3, #T_7107a_row3_col3, #T_7107a_row4_col3, #T_7107a_row5_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_7107a_row0_col4, #T_7107a_row1_col4, #T_7107a_row2_col4, #T_7107a_row3_col4, #T_7107a_row4_col4, #T_7107a_row5_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_7107a_row0_col5, #T_7107a_row1_col5, #T_7107a_row2_col5, #T_7107a_row3_col5, #T_7107a_row4_col5, #T_7107a_row5_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_7107a">
#   <caption><strong>Data Frame Summary</strong><br>train_set<br>Dimensions: 3,000,888 x 6<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_7107a_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_7107a_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_7107a_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_7107a_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_7107a_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_7107a_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7107a_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_7107a_row0_col1" class="data row0 col1" ><strong>id</strong><br>[int64]</td>
#       <td id="T_7107a_row0_col2" class="data row0 col2" >Mean (sd) : 1500443.5 (866281.9)<br>min < med < max:<br>0.0 < 1500443.5 < 3000887.0<br>IQR (CV) : 1500443.5 (1.7)</td>
#       <td id="T_7107a_row0_col3" class="data row0 col3" >3,000,888 distinct values</td>
#       <td id="T_7107a_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_7107a_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_7107a_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_7107a_row1_col1" class="data row1 col1" ><strong>date</strong><br>[object]</td>
#       <td id="T_7107a_row1_col2" class="data row1 col2" >1. 2013-01-01<br>2. 2016-01-15<br>3. 2016-02-08<br>4. 2016-02-07<br>5. 2016-02-06<br>6. 2016-02-05<br>7. 2016-02-04<br>8. 2016-02-03<br>9. 2016-02-02<br>10. 2016-02-01<br>11. other</td>
#       <td id="T_7107a_row1_col3" class="data row1 col3" >1,782 (0.1%)<br>1,782 (0.1%)<br>1,782 (0.1%)<br>1,782 (0.1%)<br>1,782 (0.1%)<br>1,782 (0.1%)<br>1,782 (0.1%)<br>1,782 (0.1%)<br>1,782 (0.1%)<br>1,782 (0.1%)<br>2,983,068 (99.4%)</td>
#       <td id="T_7107a_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_7107a_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_7107a_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_7107a_row2_col1" class="data row2 col1" ><strong>store_nbr</strong><br>[int64]</td>
#       <td id="T_7107a_row2_col2" class="data row2 col2" >Mean (sd) : 27.5 (15.6)<br>min < med < max:<br>1.0 < 27.5 < 54.0<br>IQR (CV) : 27.0 (1.8)</td>
#       <td id="T_7107a_row2_col3" class="data row2 col3" >54 distinct values</td>
#       <td id="T_7107a_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_7107a_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_7107a_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_7107a_row3_col1" class="data row3 col1" ><strong>family</strong><br>[object]</td>
#       <td id="T_7107a_row3_col2" class="data row3 col2" >1. AUTOMOTIVE<br>2. HOME APPLIANCES<br>3. SCHOOL AND OFFICE SUPPLIES<br>4. PRODUCE<br>5. PREPARED FOODS<br>6. POULTRY<br>7. PLAYERS AND ELECTRONICS<br>8. PET SUPPLIES<br>9. PERSONAL CARE<br>10. MEATS<br>11. other</td>
#       <td id="T_7107a_row3_col3" class="data row3 col3" >90,936 (3.0%)<br>90,936 (3.0%)<br>90,936 (3.0%)<br>90,936 (3.0%)<br>90,936 (3.0%)<br>90,936 (3.0%)<br>90,936 (3.0%)<br>90,936 (3.0%)<br>90,936 (3.0%)<br>90,936 (3.0%)<br>2,091,528 (69.7%)</td>
#       <td id="T_7107a_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_7107a_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_7107a_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_7107a_row4_col1" class="data row4 col1" ><strong>sales</strong><br>[float64]</td>
#       <td id="T_7107a_row4_col2" class="data row4 col2" >Mean (sd) : 357.8 (1102.0)<br>min < med < max:<br>0.0 < 11.0 < 124717.0<br>IQR (CV) : 195.8 (0.3)</td>
#       <td id="T_7107a_row4_col3" class="data row4 col3" >379,610 distinct values</td>
#       <td id="T_7107a_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_7107a_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_7107a_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_7107a_row5_col1" class="data row5 col1" ><strong>onpromotion</strong><br>[int64]</td>
#       <td id="T_7107a_row5_col2" class="data row5 col2" >Mean (sd) : 2.6 (12.2)<br>min < med < max:<br>0.0 < 0.0 < 741.0<br>IQR (CV) : 0.0 (0.2)</td>
#       <td id="T_7107a_row5_col3" class="data row5 col3" >362 distinct values</td>
#       <td id="T_7107a_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_7107a_row5_col5" class="data row5 col5" >0<br>(0.0%)</td>
#     </tr>
#   </tbody>
# </table>
#
#     </div>
#     <style>
#     #btn-7999.st-collapsible {
#       background-color: white;
#       color: #444;
#       cursor: pointer;
#       padding: 1.5rem 2rem;
#       width: 100%;
#       text-align: left;
#       outline: none;
#       font-size: 14px;
#       border-top-left-radius: 0.375rem;
#       border-top-right-radius: 0.375rem;
#       border: 1px solid #dee2e6;
#       border-bottom: none;
#       font-weight: 500;
#     }
#
#     #btn-7999.active {
#       background-color: #e7f1ff;
#       color: #0c63e4;
#     }
#
#     #cont-7999.st-content {
#       padding: 0 10px;
#       background-color: white;
#       max-height: 0;
#       overflow: hidden;
#       transition: max-height 0.2s ease-out;
#       border: 1px solid #dee2e6;
#       border-top: none;
#     }
#
#     #cont-7999.st-content .active {
#       border: 1px solid #dee2e6;
#       border-bottom-left-radius: 0.375rem;
#       border-bottom-right-radius: 0.375rem;
#     }
#
#     #btn-7999.st-collapsible:after {
#       content: '';
#       background-image: url("data:image/svg+xml,%3csvg xmlns='http://www.w3.org/2000/svg' viewBox='0 0 16 16' fill='%23212529'%3e%3cpath fill-rule='evenodd' d='M1.646 4.646a.5.5 0 0 1 .708 0L8 10.293l5.646-5.647a.5.5 0 0 1 .708.708l-6 6a.5.5 0 0 1-.708 0l-6-6a.5.5 0 0 1 0-.708z'/%3e%3c/svg%3e");
#       color: #444;
#       font-weight: bold;
#       float: right;
#       margin-left: 5px;
#       height: 1.5em;
#       width:  1.5rem;
#       background-repeat: no-repeat;
#       transition: transform 0.2s ease-in-out;
#     }
#
#     #btn-7999.active:after {
#       content: '';
#       background-image: url("data:image/svg+xml,%3csvg xmlns='http://www.w3.org/2000/svg' v

# %% [markdown]
# **Observations about the train dataframe.**
#
# -There are no missing values in the dataFrame.
#
# -The date column is an object data type.
#
# -The family column are object data types this will not be accepted by the model.

# %%
#Convert date from object to date time.

train_set['date']=pd.to_datetime(train_set.date)

# %%
plt.figure(figsize=(8,6))
train_plot = sns.catplot(data=train_set, y='family', kind='count', orient='h', height=6, aspect=1.5)
train_plot.ax.set_xlabel('Count')
train_plot.ax.set_ylabel('Family');

# %% [markdown]
# **Observation about the Family column.**
#
# -Alot of the family groupings are in the food category, these have to be regrouped for easier analyis.
#
# -There is exactly the same number of entries for all product families in the train dataset.

# %%
sns.lineplot(data=train_set, x='date', y='sales')
# Out:
# <AxesSubplot:xlabel='date', ylabel='sales'>

# %% [markdown]
# **Observation from the train_set transaction plot**.
#
# -There is an upward trend in the transactions data.
#
# -The transactions peak at the end of the year, then drops off.
#
# -There is a level of seasonality exhibited by the dataset.
#
# -This indicates seasonality in the transactions data.

# %% [markdown]
# Observation of the dataset sales column.
#
# -The highest obvervable spike in sales happened in the year 2014. Followed by 2015, 2016 and 2017 respectively.

# %% [markdown]
# # ANSWERING THE QUESTIONS.

# %% [markdown]
# **Q1.Is the train dataset complete (has all the required dates)?**

# %%
df=train_set

# %%
print(df.index.duplicated())
# Out:
# [False False False ... False False False]

# %%
df.head()
# Out:
#    id       date  store_nbr      family  sales  onpromotion
# 0   0 2013-01-01          1  AUTOMOTIVE    0.0            0
# 1   1 2013-01-01          1   BABY CARE    0.0            0
# 2   2 2013-01-01          1      BEAUTY    0.0            0
# 3   3 2013-01-01          1   BEVERAGES    0.0            0
# 4   4 2013-01-01          1       BOOKS    0.0            0

# %%
#getting dates which are not in the train dataset
missing_dates=pd.date_range(start= '2013-01-01', end='2017-08-15').difference(df.date)


print(missing_dates);
# Out:
# DatetimeIndex(['2013-12-25', '2014-12-25', '2015-12-25', '2016-12-25'], dtype='datetime64[ns]', freq=None)

# %% [markdown]
# <b>Q2.Which dates have the lowest and highest sales for each year?<b>
#
# -Here the train_set DataFrame is used

# %%
# Group the dataframe by year and apply the calculation for each year
result = df.groupby(df['date'].dt.year).apply(lambda x: pd.Series({
    'max_sales_date': x.loc[x['sales'].idxmax(), 'date'],
    'max_sales_value': x.loc[x['sales'].idxmax(), 'sales'],
    'min_sales_date': x.loc[x['sales'].idxmin(), 'date'],
    'min_sales_value': x.loc[x['sales'].idxmin(), 'sales']
}))

print(result)
# Out:
#      max_sales_date  max_sales_value min_sales_date  min_sales_value
# date
# 2013     2013-11-12        46271.000     2013-01-01              0.0
# 2014     2014-12-08        45361.000     2014-01-01              0.0
# 2015     2015-12-14        40351.460     2015-01-01              0.0
# 2016     2016-05-02       124717.000     2016-01-01              0.0
# 2017     2017-04-02        38422.625     2017-01-01              0.0

# %% [markdown]
# <b>Q3:Did the earthquake impact sales?<b>

# %%
#Set Date as the index for the df DataFrame
df = df.set_index('date')

# %%
df['Year']=date.year
df['Month']=date.month
df['Day Name']=date.day_name()

# %%
df.head()
# Out:
#             id  store_nbr      family  sales  onpromotion  Year  Month  \
# date
# 2013-01-01   0          1  AUTOMOTIVE    0.0            0  2013      1
# 2013-01-01   1          1   BABY CARE    0.0            0  2013      1
# 2013-01-01   2          1      BEAUTY    0.0            0  2013      1
# 2013-01-01   3          1   BEVERAGES    0.0            0  2013      1
# 2013-01-01   4          1       BOOKS    0.0            0  2013      1
#
#            Day Name
# date
# 2013-01-01  Tuesday
# 2013-01-01  Tuesday
# 2013-01-01  Tuesday
# 2013-01-01  Tuesday
# 2013-01-01  Tuesday

# %%
april_2016 = df.loc['2016-04-01':'2016-04-30']
plt.plot(april_2016.index, april_2016['sales'])
plt.xticks(rotation=45)
plt.xlabel('Date')
plt.ylabel('Sales')
plt.title('Sales in April 2016')
plt.show()

# %% [markdown]
# Yes the earthquake had an impact on sales.
# The earth quake occured on the 16th of April, looking at the chart it shows that sales increased to about 30000 on the 17th of April.
# However, on the 18th of April, that is two (2) days after the earth quake sales shot up to 75000. This can be attributed to the after effect of the earth quake. Sales dropped to about 250000 on the 19th of April.
# There was a further jump in sales to about 87000 on the 21st of April and 62000 on the 26th of April, these sales jump can be attributed to the after effect earth quake.

# %% [markdown]
# <b>Q4:Are certain groups of stores selling more products? (Cluster, city, state, type)<b>

# %%
#First merge the stores DataFrame and transactions DataFrame
performance_df=pd.merge(df_transactions,df_stores,on='store_nbr',how='outer')

# %% [markdown]
# <b>Analysing by city<b>

# %%
# group the data by city and count the values, then sort by the count values in descending order
city_counts = performance_df.groupby('city')['city'].count().sort_values(ascending=False)

# create a new figure object with the desired dimensions
plt.figure(figsize=(10, 6))

# create a count plot with the 'city' column on the x-axis and sorted data
sns.countplot(data=performance_df, x='city', order=city_counts.index)

# set the y-label
plt.ylabel('Transaction Count')

# set the title
plt.title('Volume of Transactions by City')

# rotate x-axis labels to make them readable
plt.xticks(rotation=45)

# show the plot
plt.show()

# %% [markdown]
# <b>Analysis of cluster perfromance<b>

# %%
# group the data by city and count the values, then sort by the count values in descending order
city_counts = performance_df.groupby('cluster')['cluster'].count().sort_values(ascending=False)

# create a new figure object with the desired dimensions
plt.figure(figsize=(10, 6))

# create a count plot with the 'city' column on the x-axis and sorted data
sns.countplot(data=performance_df, x='cluster', order=city_counts.index)

# set the y-label
plt.ylabel('Transaction Count')

# set the title
plt.title('Volume of Transactions by cluster')

# rotate x-axis labels to make them readable
plt.xticks(rotation=45)

# show the plot
plt.show()

# %% [markdown]
# <b>Analysing sales by state<b>

# %%
# group the data by city and count the values, then sort by the count values in descending order
city_counts = performance_df.groupby('state')['state'].count().sort_values(ascending=False)

# create a new figure object with the desired dimensions
plt.figure(figsize=(10, 6))

# create a count plot with the 'city' column on the x-axis and sorted data
sns.countplot(data=performance_df, x='state', order=city_counts.index)

# set the y-label
plt.ylabel('Transaction Count')

# set the title
plt.title('Volume of Transactions by state')

# rotate x-axis labels to make them readable
plt.xticks(rotation=45)

# show the plot
plt.show()

# %% [markdown]
# <b>Analysis by type<b>

# %%
# group the data by city and count the values, then sort by the count values in descending order
city_counts = performance_df.groupby('type')['type'].count().sort_values(ascending=False)

# create a new figure object with the desired dimensions
plt.figure(figsize=(10, 6))

# create a count plot with the 'city' column on the x-axis and sorted data
sns.countplot(data=performance_df, x='type', order=city_counts.index)

# set the y-label
plt.ylabel('Transaction Count')

# set the title
plt.title('Volume of Transactions by type')

# show the plot
plt.show()

# %% [markdown]
# <b>Q5:Are sales affected by promotions, oil prices and holidays?<b>

# %% [markdown]
# <b>Sales Vrs promotions Analysis<b>

# %%
#Merge the train_set,oil and holiday events DataFrames

new_train=pd.merge(train_set,df_oil,left_on=['date'],right_on=['date'],how='inner').merge(df_holiday_events,on=['date'],how='inner')

# %%
# plot sales and promotions against dates
plt.plot(new_train['date'], new_train['sales'], label='Sales')
plt.plot(new_train['date'], new_train['onpromotion'], label='Promotions')

# add title and axis labels
plt.title('Sales and Promotions Over Time')
plt.xlabel('Date')
plt.ylabel('Amount')

# add legend
plt.legend()

# display the plot
plt.show()

# %%
# compute correlation between sales and promotions
corr = df['sales'].corr(df['onpromotion'])

# correlation coefficient
print(f"Correlation coefficient between sales and promotions: {corr:.2f}")
# Out:
# Correlation coefficient between sales and promotions: 0.43

# %% [markdown]
# A correlation coefficient of 0.43 indicates a moderate positive correlation between the two variables being compared.
#
# In this case, the two variables are sales and promotions, a correlation coefficient of 0.43 suggests that there is a moderate positive relationship between the amount of promotions and the amount of sales. This means that as the amount of promotions increases, the amount of sales tends to increase as well, but not necessarily in a linear fashion.

# %% [markdown]
# <b>Sales vrs Oil<b>

# %%
# plot sales and oil prices against dates
plt.plot(new_train['date'], new_train['sales'], label='Sales')
plt.plot(new_train['date'], new_train['dcoilwtico'], label='Oil')

# add title and axis labels
plt.title('Sales and Oil Price Over Time')
plt.xlabel('Date')
plt.ylabel('Amount')

# add legend
plt.legend()

# display the plot
plt.show()

# %%
# compute correlation between sales and promotions
corr = new_train['sales'].corr(new_train['dcoilwtico'])

# correlation coefficient
print(f"Correlation coefficient between sales and oil price: {corr:.2f}")
# Out:
# Correlation coefficient between sales and oil price: -0.07

# %% [markdown]
# A correlation coefficient of -0.07 suggests a weak negative correlation between the two variables being compared.
# The negative sign indicates that there is a negative relationship between the two variables, meaning that as one variable increases, the other tends to decrease, although the correlation is weak, which suggests that the relationship is not very strong.

# %% [markdown]
# <b>Sales Vrs Holidays<b>

# %%
holiday_sales = new_train.groupby('type')['sales'].sum().reset_index()
holiday_sales['Cumulative_Percentage'] = (holiday_sales['sales'].cumsum() / holiday_sales['sales'].sum()) * 100
holiday_sales = holiday_sales.sort_values(by='sales', ascending=False)

holiday_sales
# Out:
#          type         sales  Cumulative_Percentage
# 3     Holiday  7.525080e+07              94.916414
# 2       Event  2.511684e+07              37.425222
# 0  Additional  2.148108e+07              16.411428
# 4    Transfer  6.653957e+06             100.000000
# 1      Bridge  2.388330e+06              18.236099

# %%
fig, ax1 = plt.subplots()
ax1.bar(holiday_sales['type'], holiday_sales['sales'], color='C0')
ax1.set_ylabel('Sales')
ax1.tick_params(axis='y')

ax2 = ax1.twinx()
ax2.plot(holiday_sales['type'], holiday_sales['Cumulative_Percentage'], color='C1', marker='o')
ax2.set_ylabel('Cumulative Percentage')
ax2.tick_params(axis='y')

plt.title('Pareto Chart of Sales by Holiday Type')
plt.show()

# %%
import scipy.stats as stats

# Group the data by type of holiday
groups = new_train.groupby('type')['sales'].apply(list)

# Perform ANOVA test
f_value, p_value = stats.f_oneway(*groups)

print(f"One-way ANOVA results: F = {f_value:.2f}, p-value = {p_value:.4f}")
# Out:
# One-way ANOVA results: F = 194.19, p-value = 0.0000

# %% [markdown]
# Based on the results of the ANOVA test, we can conclude that there is a significant difference in sales between the different types of holidays. This means that the type of holiday has an impact on the sales. However, the ANOVA test does not tell us which specific type of holiday is responsible for the difference in sales. To determine that, we would need to perform additional analyses such as post-hoc tests or pairwise comparisons.

# %% [markdown]
# <b>Q6:What analysis can we get from the date and its extractable features?<b>

# %% [markdown]
# **The extractable features from the date are Year,Month and Day.**
#
# **Year**:At the high level we can analyse the sales performance across the years for a specific store,city, state, product family or cluster.
#
# **Month**: The next level of drill down will be analysing sales performance monthly for stors,cities, states, product families and clusteres. The analysis can cover corresponding months acoss years that is you can analyse sales in the month of January for all years. This will show whether there is seasonality or not.
#
# **Day of week**: Day of week provides a further level of detail to the analysis that can be done.<b>

# %% [markdown]
# <b>MODELLING AND PREDICTIONS<b>

# %% [markdown]
# **FB PROPHET MODEL**
#
# The first model for prediction is the prophet model from Facebook

# %%
#Read in the train_data specifically for the prophet model
#We restricted the columns to only the sales and date.

train_set_pr=pd.read_csv("store-sales-time-series-forecasting/train.csv",usecols=['date','sales'])

# %%
train_set_pr.head()
# Out:
#          date  sales
# 0  2013-01-01    0.0
# 1  2013-01-01    0.0
# 2  2013-01-01    0.0
# 3  2013-01-01    0.0
# 4  2013-01-01    0.0

# %%
#We check the size and memory required for the train_set_pr DataFrame

train_set_pr.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000888 entries, 0 to 3000887
# Data columns (total 2 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   date    object
#  1   sales   float64
# dtypes: float64(1), object(1)
# memory usage: 214.6 MB

# %%
#To use the forest model, the columns names for date and sales have to be changed to ds and y respectively
train_set_pr.columns=['ds','y']

# %%
train_set_pr.head()
# Out:
#            ds    y
# 0  2013-01-01  0.0
# 1  2013-01-01  0.0
# 2  2013-01-01  0.0
# 3  2013-01-01  0.0
# 4  2013-01-01  0.0

# %%
#The notebook kept crashing when we tried to train the model. We therefore decided to use only one million rows from the DataFrame of three million rows.

sample_data=train_set_pr.sample(n=1000000)

# %%
#The model is named 'model'

model=Prophet()

# %%
#Training the model

model.fit(sample_data)
# Out:
# 23:01:49 - cmdstanpy - INFO - Chain [1] start processing
# 23:04:49 - cmdstanpy - INFO - Chain [1] done processing

# %%
#Create future dates over a period of year which will be used to make predictions using the model.

future_dates=model.make_future_dataframe(periods=365)

# %%
#Make predictions using the model

prediction=model.predict(future_dates)

# %%
prediction
# Out:
#              ds       trend   yhat_lower   yhat_upper  trend_lower  \
# 0    2013-01-01  167.536088 -1180.733485  1590.953217   167.536088
# 1    2013-01-02  167.994660 -1167.324203  1620.047295   167.994660
# 2    2013-01-03  168.453233 -1272.384343  1524.333941   168.453233
# 3    2013-01-04  168.911806 -1278.626907  1556.961127   168.911806
# 4    2013-01-05  169.370378  -984.207042  1812.184826   169.370378
# ...         ...         ...          ...          ...          ...
# 2044 2018-08-11  583.324113  -953.710761  2116.219576    50.091229
# 2045 2018-08-12  583.532445  -894.172249  2246.634381    47.368707
# 2046 2018-08-13  583.740777 -1001.775380  1959.712380    45.204494
# 2047 2018-08-14  583.949109 -1099.893786  2063.156103    43.128379
# 2048 2018-08-15  584.157442  -952.953133  2149.103693    41.052263
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0      167.536088       29.180832             29.180832             29.180832
# 1      167.994660       38.353919             38.353919             38.353919
# 2      168.453233      -20.801204            -20.801204            -20.801204
# 3      168.911806       17.505443             17.505443             17.505443
# 4      169.370378      121.158199            121.158199            121.158199
# ...           ...             ...                   ...                   ...
# 2044  1089.098750       29.797713             29.797713             29.797713
# 2045  1092.198569       53.211734             53.211734             53.211734
# 2046  1095.140008      -59.747383            -59.747383            -59.747383
# 2047  1097.084826      -89.333870            -89.333870            -89.333870
# 2048  1099.029644      -73.601725            -73.601725            -73.601725
#
#           weekly  weekly_lower  weekly_upper     yearly  yearly_lower  \
# 0     -39.267272    -39.267272    -39.267272  68.448104     68.448104
# 1     -23.666653    -23.666653    -23.666653  62.020572     62.020572
# 2     -76.354055    -76.354055    -76.354055  55.552851     55.552851
# 3     -31.638782    -31.638782    -31.638782  49.144224     49.144224
# 4      78.268839     78.268839     78.268839  42.889360     42.889360
# ...          ...           ...           ...        ...           ...
# 2044   78.268839     78.268839     78.268839 -48.471126    -48.471126
# 2045  102.541241    102.541241    102.541241 -49.329507    -49.329507
# 2046   -9.883319     -9.883319     -9.883319 -49.864064    -49.864064
# 2047  -39.267272    -39.267272    -39.267272 -50.066598    -50.066598
# 2048  -23.666653    -23.666653    -23.666653 -49.935072    -49.935072
#
#       yearly_upper  multiplicative_terms  multiplicative_terms_lower  \
# 0        68.448104                   0.0                         0.0
# 1        62.020572                   0.0                         0.0
# 2        55.552851                   0.0                         0.0
# 3        49.144224                   0.0                         0.0
# 4        42.889360                   0.0                         0.0
# ...            ...                   ...                         ...
# 2044    -48.471126                   0.0                         0.0
# 2045    -49.329507                   0.0                         0.0
# 2046    -49.864064                   0.0                         0.0
# 2047    -50.066598                   0.0                         0.0
# 2048    -49.935072                   0.0                         0.0
#
#       multiplicative_terms_upper        yhat
# 0                            0.0  196.716919
# 1                            0.0  206.348580
# 2                            0.0  147.652029
# 3                            0.0  186.417248
# 4                            0.0  290.528577
# ...                          ...         ...
# 2044                         0.0  613.121827
# 2045                         0.0  636.744179
# 2046                         0.0  523.993394
# 2047                         0.0  494.615240
# 2048                         0.0  510.555717
#
# [2049 rows x 19 columns]

# %%
#Visualize the results to show the actual and predicted sales

fig, ax = plt.subplots(figsize=(10, 5))
fig = model.plot(prediction, ax=ax)

ax.set_xlabel('Date')
ax.set_ylabel('Value')

ax.legend(['Actual', 'Predicted'], loc='upper left')

plt.show()

# %%
#Prophet model allows for visualising the 'headline' trend,weekly trend and yearly trend.

fig=model.plot_components(prediction)
plt.show()

# %% [markdown]
# #**Observations**
#
# -Trend: The highlevel trend indicates a positive growth in sales from 2013 to 2017 onwards. 2018 represents predicted sales with confidence interval.
#
# -Weekly trend analysis shows that sales jumps exponentially from Thursday towards the weekend. This implies customers make their purchases close to the weekend.
#
# -The monthly data indicates seasonality in the trend. From November when shopping towards Christmas festivities happen,we notice a rise in sales till the new year on 1st January. Sales then level of for the rest of the year till another November comes around.

# %%
# Plot actual and predicted values

plt.rcParams['agg.path.chunksize'] = 1000

plt.figure(figsize=(10, 5))
plt.plot(sample_data.index, sample_data['y'], label='Actual')
plt.plot(prediction.index, prediction['yhat'], label='Predicted')
plt.legend()
plt.show()

# %% [markdown]
# # **ARIMA MODEL**

# %%
train_ar=pd.read_csv('store-sales-time-series-forecasting/train.csv')
test_ar=pd.read_csv('store-sales-time-series-forecasting/test.csv')

# %%
#Change the date format from object to datetime
train_ar['date'] = pd.to_datetime(train_ar['date'])
test_ar['date'] = pd.to_datetime(test_ar['date'])

# %%
#Set the date as the index for both datasets

train_ar = train_ar.set_index('date')
test_ar= test_ar.set_index('date')

# %%
train_ar.drop(['id','family'], axis=1, inplace=True)

# %%
train_ar.drop(['store_nbr'], axis=1, inplace=True)

# %%
train_ar.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
# Fit ARIMA model
model_ar = ARIMA(train_ar['sales'], order=(1,1,1))
model_fit_ar = model_ar.fit()

# %%
# Make predictions on the test set
test_ar['predicted_sales'] = model_fit_ar.forecast(steps=len(test_ar))

# %% [markdown]
# **LINEAR REGRESSION**

# %%
train_lr=pd.read_csv('store-sales-time-series-forecasting/train.csv')
test_lr=pd.read_csv('store-sales-time-series-forecasting/test.csv')

# %%
test_lr.head()
# Out:
#         id        date  store_nbr      family  onpromotion
# 0  3000888  2017-08-16          1  AUTOMOTIVE            0
# 1  3000889  2017-08-16          1   BABY CARE            0
# 2  3000890  2017-08-16          1      BEAUTY            2
# 3  3000891  2017-08-16          1   BEVERAGES           20
# 4  3000892  2017-08-16          1       BOOKS            0

# %%
#Change the date format from object to datetime
train_lr['date'] = pd.to_datetime(train_lr['date'])
test_lr['date'] = pd.to_datetime(test_lr['date'])

# %%
#Set the date as the index for both datasets

train_lr = train_lr.set_index('date')
test_lr= test_lr.set_index('date')

# %%
# Define the dependent and independent variables
X_train = train_lr[['onpromotion']]
y_train = train_lr['sales']
x_test=test_lr[['onpromotion']]

# %%
# Train linear regression model on train data
lr_model = LinearRegression()

# %%
#Training the model
lr_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#Predict the sales for the test data

y_test_pred = lr_model.predict(x_test)

# %%
# Add predicted sales column to test data
test_lr['predicted_sales'] = y_test_pred

# %% [markdown]
# **VISUALISING THE ACTUAL SALES VRS PREDICTED SALES**

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(12,5))

# Plot predicted sales in test data
ax[0].scatter(test_lr.index, test_lr['predicted_sales'])
ax[0].set_xlabel('Date')
ax[0].set_ylabel('Predicted Sales')
ax[0].set_title('Predicted Sales')

# Plot actual sales in train data
ax[1].scatter(train_lr.index, train_lr['sales'])
ax[1].set_xlabel('Date')
ax[1].set_ylabel('Actual Sales')
ax[1].set_title('Actual Sales')

# Create space between the two subplots
fig.tight_layout(pad=3.0)

# Show the plot
plt.show()
